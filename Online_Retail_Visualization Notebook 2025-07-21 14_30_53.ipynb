# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# set the graphs to show in the jupyter notebook
# %matplotlib inline 
# set seaborn graphs to a better style
sns.set(style="ticks")

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Online_Retail/Online_Retail.csv"

online_rt = pd.read_csv(url, encoding = 'latin1')
online_rt.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
# group by the Country
countries = online_rt.groupby('Country').sum()
#sort the value and get the first 10 after UK
countries = countries.sort_values(by = 'Quantity',ascending = False)[1:11]
# create the plot
countries['Quantity'].plot(kind='bar')
# Set the title and labels
plt.xlabel('Countries')
plt.ylabel('Quantity')
plt.title('10 Countries with most orders')
# show the plot
plt.show()
# Out:
# /home/spark-924b96cf-bfc2-4642-80b4-ac/.ipykernel/2848/command-8027485838691615-2657439547:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   countries = online_rt.groupby('Country').sum()

# %%
online_rt = online_rt[online_rt.Quantity > 0]
online_rt.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Online_Retail/Online_Retail.csv"
online_rt = pd.read_csv(url, encoding='ISO-8859-1')

# Group by CustomerID and Country
customers = online_rt.groupby(['CustomerID', 'Country']).sum()

# Remove rows with negative or zero unit price
customers = customers[customers.UnitPrice > 0]

# Extract 'Country' from the index and make it a column
customers['Country'] = customers.index.get_level_values(1)

# Top 3 countries
top_countries = ['Netherlands', 'EIRE', 'Germany']

# Filter to only those top countries
customers = customers[customers['Country'].isin(top_countries)]

# Create a FacetGrid for scatter plots
g = sns.FacetGrid(customers, col="Country")
g.map(plt.scatter, "Quantity", "UnitPrice", alpha=1)
g.add_legend()

# Show the plot
plt.show()
# Out:
# /home/spark-924b96cf-bfc2-4642-80b4-ac/.ipykernel/2848/command-8027485838691617-2892343881:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   customers = online_rt.groupby(['CustomerID', 'Country']).sum()
# /databricks/python/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#This takes our initial dataframe groups it primarily by 'CustomerID' and secondarily by 'Country'.
#It sums all the (non-indexical) columns that have numerical values under each group.
customers = online_rt.groupby(['CustomerID','Country']).sum().head()
#Here's what it looks like:
customers
# Out:
# /home/spark-924b96cf-bfc2-4642-80b4-ac/.ipykernel/2848/command-8027485838691618-4115421268:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   customers = online_rt.groupby(['CustomerID','Country']).sum().head()
#                            Quantity  UnitPrice
# CustomerID Country
# 12346.0    United Kingdom         0       2.08
# 12347.0    Iceland             2458     481.21
# 12348.0    Finland             2341     178.71
# 12349.0    Italy                631     605.10
# 12350.0    Norway               197      65.30

# %%
import pandas as pd

# Load the data
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Online_Retail/Online_Retail.csv"
online_rt = pd.read_csv(url, encoding='ISO-8859-1')

# Group by CustomerID and Country, summing Quantity only
customers = online_rt.groupby(['CustomerID', 'Country'])[['Quantity']].sum().reset_index()

# Check the data type of UnitPrice
print("UnitPrice dtype:", online_rt['UnitPrice'].dtype)  # So it's 'float64'

# ✍️ Commentary:
# But why did we sum 'UnitPrice' to begin with?
# Summing it is misleading—it doesn’t show actual spending patterns.
# Two customers may spend the same amount in very different ways.

# Let’s check two specific customers for evidence
display(online_rt[online_rt.CustomerID == 12347.0].sort_values(by='UnitPrice', ascending=False).head())
display(online_rt[online_rt.CustomerID == 12346.0].sort_values(by='UnitPrice', ascending=False).head())

# ✍️ Observation:
# Customer 12346.0 placed one giant order,
# whereas 12347.0 placed many smaller ones.
# Both spent similar amounts, but with very different behavior.

# ✅ Conclusion:
# Avoid summing UnitPrice. Use average, total spend (Quantity * UnitPrice), or order counts instead.
# Out:
# UnitPrice dtype: float64
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
import pandas as pd

# Load the dataset
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Online_Retail/Online_Retail.csv"
online_rt = pd.read_csv(url, encoding='ISO-8859-1')

# Group by Country and sum Quantity
sales_volume = online_rt.groupby('Country')['Quantity'].sum().sort_values(ascending=False)

# Exclude top country (UK) and get next 3
top3 = sales_volume.index[1:4]

print("Top 3 countries by Quantity (excluding UK):")
print(top3)
# Out:
# Top 3 countries by Quantity (excluding UK):
# Index(['Netherlands', 'EIRE', 'Germany'], dtype='object', name='Country')

# %%
 online_rt['Revenue'] = online_rt.Quantity * online_rt.UnitPrice
 online_rt.head()
# Out:
#   InvoiceNo StockCode  ...         Country  Revenue
# 0    536365    85123A  ...  United Kingdom    15.30
# 1    536365     71053  ...  United Kingdom    20.34
# 2    536365    84406B  ...  United Kingdom    22.00
# 3    536365    84029G  ...  United Kingdom    20.34
# 4    536365    84029E  ...  United Kingdom    20.34
#
# [5 rows x 9 columns]

# %%
grouped = online_rt[online_rt.Country.isin(top3)].groupby(['CustomerID','Country'])
plottable = grouped['Quantity','Revenue'].agg('sum')
plottable['AvgPrice'] = plottable.Revenue / plottable.Quantity
# get the value of the index and put in the column Country
plottable['Country'] = plottable.index.get_level_values(1)
plottable.head()
# Out:
# /home/spark-924b96cf-bfc2-4642-80b4-ac/.ipykernel/2848/command-8027485838691626-3761250149:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   plottable = grouped['Quantity','Revenue'].agg('sum')
#                     Quantity   Revenue  AvgPrice  Country
# CustomerID Country
# 12426.0    Germany       258    582.73  2.258643  Germany
# 12427.0    Germany       236    708.37  3.001568  Germany
# 12468.0    Germany       364    724.04  1.989121  Germany
# 12471.0    Germany      7965  18740.92  2.352909  Germany
# 12472.0    Germany      4020   6229.48  1.549622  Germany

# %%
####################
# Graph Section v 2#
####################
# creates the FaceGrid
g = sns.FacetGrid(plottable, col="Country")
# map over a make a scatterplot
g.map(plt.scatter, "Quantity", "AvgPrice", alpha=1)
# adds legend
g.add_legend()
# Out:
# /databricks/python/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
grouped = online_rt.groupby(['CustomerID'])
plottable =grouped['Quantity','Revenue'].agg('sum')
plottable['AvgPrice'] =plottable.Revenue 
plottable.head
# map over a make a scatterplot
plt.scatter(plottable.Quantity, plottable.AvgPrice)
plt.plot()
plottable.Quantity
#Turns out the graph is still extremely skewed towards the axes like an exponential decay function.
[]
# Out:
# /home/spark-924b96cf-bfc2-4642-80b4-ac/.ipykernel/2848/command-8027485838691629-3604755067:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   plottable =grouped['Quantity','Revenue'].agg('sum')
# []

# %%
grouped = online_rt.groupby (['CustomerID','Country'])
plottable = grouped.agg({'Quantity': 'sum',
                         'Revenue': 'sum'})
plottable['Avgprice'] = plottable.Revenue / plottable.Quantity

#map over a make a scatterplot
plt.scatter(plottable['Quantity'], plottable['Avgprice'])

#Zooming in.(I'm starting the axes from a negative value so that
#the dots can be plotted in the graph completely.)
plt.xlim(-40,2000)
plt.ylim(-1,80)

plt.plot()

#And there is still that pattern, this time in close-up!
[]
# Out:
# []

# %%
#These are the values for the graph.
#They are used both in selecting data from
#the DataFrame and plotting the data so I've assigned
#them to variables to increase consistency and make things easier
#when playing with the variables.
price_start = 0 
price_end = 50
price_interval = 1
#Creating the buckets to collect the data accordingly
buckets =np.arange(price_start,price_end,price_interval)
#Select the data and sum
revenue_per_price =online_rt.groupby(pd.cut(online_rt.UnitPrice, buckets)).Revenue.sum()
revenue_per_price.head()
# Out:
# UnitPrice
# (0, 1]    1089068.414
# (1, 2]    2557511.340
# (2, 3]    1803381.940
# (3, 4]     849919.340
# (4, 5]    1199346.770
# Name: Revenue, dtype: float64

# %%
revenue_per_price.plot()
plt.xlabel('Unit Price (in intervals of '+str(price_interval)+')')
plt.ylabel('Revenue')
plt.show()

# %%
revenue_per_price.plot()
#Place labels
plt.xlabel( 'Unit Price (in buckets of '+str(price_interval)+')')
plt.ylabel('Revenue')
#Even though the data is bucketed in intervals of 1,
#I'll plot ticks a little bit further apart from each other to avoid cluttering.
plt.xticks(np.arange(price_start,price_end,3),
           np.arange(price_start,price_end,3))
plt.yticks([0, 500000, 1000000, 1500000, 2000000, 2500000],
           ['0','$0.5M','$1M','$1.5M','$2M','$2.5'])
plt.show()           

 #Looks like a major chunk of our revenue comes from items worth $0-$3!
